# %% [markdown]
# #Read Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#import the dataset
data = pd.read_csv('/content/drive/MyDrive/SIB - Bisa AI Academy/WEBINAR/Introduction Unsupervised Learning - Kmeans /nilaisiswa.csv',delimiter=';')
data.shape
# Out:
# (50, 3)

# %%
data.head()
# Out:
#    Mahasiswa  Rata-rata nilai IPA  Rata-rata nilai IPS
# 0      AHMAD                   15                   46
# 1    ARFENDO                   66                   77
# 2  LATIFUDIN                   25                   33
# 3      HENDI                   53                   81
# 4  M. FERYAN                   20                   75

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Mahasiswa            50 non-null     object
#  1   Rata-rata nilai IPA  50 non-null     int64
#  2   Rata-rata nilai IPS  50 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.3+ KB

# %%
plt.scatter(data['Rata-rata nilai IPA'],data['Rata-rata nilai IPS'])
plt.xlabel("Rata-rata nilai IPA")
plt.ylabel("Rata-rata nilai IPS")
plt.title("Grafik Nilai Mahasiswa")
# Out:
# Text(0.5, 1.0, 'Grafik Nilai Mahasiswa')

# %%
data = data.set_index('Mahasiswa')
data.head()
# Out:
#            Rata-rata nilai IPA  Rata-rata nilai IPS
# Mahasiswa
# AHMAD                       15                   46
# ARFENDO                     66                   77
# LATIFUDIN                   25                   33
# HENDI                       53                   81
# M. FERYAN                   20                   75

# %%
#define x
x = data

#check the shape of x
print(x.shape)
# Out:
# (50, 2)

# %% [markdown]
# #Clustering

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=2)
kmeans.fit(x)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=2)

# %%
x['Labels']=kmeans.labels_
x
# Out:
#                  Rata-rata nilai IPA  Rata-rata nilai IPS  Labels
# Mahasiswa
# AHMAD                             15                   46       1
# ARFENDO                           66                   77       0
# LATIFUDIN                         25                   33       1
# HENDI                             53                   81       0
# M. FERYAN                         20                   75       1
# RENDI                            100                   94       0
# NUREKA                            55                   69       0
# INDRA                             25                   56       1
# MOCH IDWAL                        25                   81       1
# REYNO YUSUF                       30                   48       1
# AHMAD MINANUL                     15                   45       1
# AFIZZA                            81                   46       0
# RIO                               68                   77       0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 4))
sns.scatterplot(x='Rata-rata nilai IPA', y='Rata-rata nilai IPS', hue='Labels', data=x,
                palette=sns.color_palette('hls', 3))

plt.title('KMeans dengan 3 Cluster')
plt.show()
# Out:
# <ipython-input-17-4d67801d9264>:5: UserWarning: The palette list has more values (3) than needed (2), which may not be intended.
#   sns.scatterplot(x='Rata-rata nilai IPA', y='Rata-rata nilai IPS', hue='Labels', data=x,

# %%
kmeans.cluster_centers_
# Out:
# array([[78.24, 78.36,  1.4 ],
#        [34.2 , 43.56,  0.16]])

# %%
plt.figure(figsize=(8, 4))
sns.scatterplot(x='Rata-rata nilai IPA', y='Rata-rata nilai IPS', hue='Labels', data=x,
                palette=sns.color_palette('hls', 3))

# plt.scatter(kmeans.cluster_centers_[0,0], kmeans.cluster_centers_[0,1], cmap='rainbow', marker='*',s=150, label='Centroid 0')
# plt.scatter(kmeans.cluster_centers_[1,0],kmeans.cluster_centers_[1,1],cmap='rainbow', marker='*',s=150, label='Centroid 1')
# plt.scatter(kmeans.cluster_centers_[2,0],kmeans.cluster_centers_[2,1],cmap='rainbow', marker='*',s=150, label='Centroid 2')
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:, 1], s = 50, c = 'blue' , label = 'centeroid')
plt.legend()
plt.title('KMeans dengan 3 Cluster')
plt.show()
# Out:
# <ipython-input-19-c39d6c8dcf74>:2: UserWarning: The palette list has more values (3) than needed (2), which may not be intended.
#   sns.scatterplot(x='Rata-rata nilai IPA', y='Rata-rata nilai IPS', hue='Labels', data=x,

# %% [markdown]
# #Metode ELbow

# %%
from sklearn.cluster import KMeans

wcss =[]
for i in range (1,11):
  km = KMeans(n_clusters =i , init = "k-means++",max_iter=300,n_init=10,random_state=0)
  km.fit(x)
  wcss.append(km.inertia_)


plt.figure(figsize=(15,5))
plt.plot(range(1,11), wcss,'bo-')
plt.title('The Elbow Method',fontsize = 20)
plt.xlabel('No. of CLuster')
plt.ylabel('wcss')
plt.grid()
plt.show()

# %% [markdown]
# #Membuat Data Baru Hasil Clustering

# %%
x['Labels'] = x['Labels'].replace([0,1],['Baik','Kurang'])
x.head()
# Out:
#            Rata-rata nilai IPA  Rata-rata nilai IPS  Labels
# Mahasiswa
# AHMAD                       15                   46  Kurang
# ARFENDO                     66                   77    Baik
# LATIFUDIN                   25                   33  Kurang
# HENDI                       53                   81    Baik
# M. FERYAN                   20                   75  Kurang
